# %% [markdown]
# # Sentiment Analysis: Análisis de Error
#
# ¿Porqué anda mal el modelo con filtrado de stopwords?

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from util import load_datasets
train, dev, test = load_datasets()
X_train, y_train = train
X_dev, y_dev = dev
X_test, y_test = test

# %% [markdown]
# ## Actual Estado del Arte + Stop Words

# %%
from model import build_pipeline

pipeline = build_pipeline()
pipeline.set_params(vect__stop_words='english')
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.9, max_features=None, min_df=3,
#         ngram_range=(1, 5), preprocessor=None, stop_words='english',
#         s...nalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
from util import print_eval
print_eval(pipeline, X_dev, y_dev)
# Out:
# accuracy	0.85
#
#              precision    recall  f1-score   support
#
#         neg       0.86      0.86      0.86       162
#         pos       0.84      0.83      0.84       138
#
# avg / total       0.85      0.85      0.85       300
#
# [[140  22]
#  [ 23 115]]

# %% [markdown]
# ## Listar Errores
#
# Veamos en qué se equivocó.

# %%
y_pred = pipeline.predict(X_dev)

# %%
import pandas as pd
# pd.options.display.max_colwidth = 0

errors = []
for x, y1, y2 in zip(X_dev, y_dev, y_pred):
    if y1 != y2:
        errors.append({
            'item': x,
            'true': y1,
            'pred': y2})

errdf = pd.DataFrame(errors)
errdf['len'] = errdf['item'].apply(lambda x: len(x))

# %%
errdf
# Out:
#                                                  item  pred  true    len
# 0   b'topless women talk about their lives falls i...     1     0   2535
# 1   b' " the red violin " is a cold , sterile feat...     1     0   2038
# 2   b'it was a rainy friday afternoon in columbus ...     0     1   3237
# 3   b'bob the happy bastard\'s quickie review : \n...     0     1   1887
# 4   b"well i'll be damned . . . \nthe canadians ca...     0     1   2545
# 5   b"warning : anyone offended by blatant , leeri...     0     1   1917
# 6   b'senseless ( r ) marlon wayans is a very tale...     1     0   2665
# 7   b"just look back two years ago at the coen bro...     0     1   4063
# 8   b'synopsis : nice girl susanne has sex with he...     1     0   2275
# 9   b' * * * the following review contains some ha...     1     0   6766
# 10  b'on seeing the outrageous previews for bulwor...     0     1   6080
# 11  b'when i was growing up in 1970s , boys in my ...     0     1   4524
# 12  b'whenever studio executives try to combine th...     0     1   3039
# 13  b'do film critics have morals ? \nare there an...     0     1   8128
# 14  b'plot : a little boy born in east germany ( n...     1     0   4825
# 15  b' " you can\'t have any of this . \nit\'s all...     1     0   7351
# 16  b"let's face it : since waterworld floated by ...     0     1   1211
# 17  b'bob the happy bastard\'s quickie review : \n...     0     1   2104
# 18  b'capsule : the weakest and least engaging of ...     1     0   2540
# 19  b'it\'s ironic that the best films in cinema h...     0     1   3548
# 20  b"an indian runner was more than a courier . \...     0     1   2221
# 21  b'it might surprise some to know that joel and...     0     1   4007
# 22  b'in the interest of being generous , i want t...     1     0   6136
# 23  b"running time approximately 1hr 40mins \nrevi...     1     0   2718
# 24  b"this is a film that i was inclined to like a...     1     0   2906
# 25  b'i was recently told that in china their had ...     1     0   4426
# 26  b'the marvelous british actor derek jacobi sta...     1     0   3516
# 27  b' " the blair witch project " was perhaps one...     0     1   6062
# 28  b"let me first say that the conditions that i ...     0     1   5244
# 29  b'it was with great trepidation that i approac...     0     1   4079
# 30  b'if beavis and butthead had a favorite movie ...     0     1   3385
# 31  b"here's a rarity : a children's film that att...     1     0   2708
# 32  b'what do you get when you combine clueless an...     0     1   2860
# 33  b'capsule : the much anticipated re-adaptation...     1     0   8545
# 34  b'it\'s almost amusing to watch 21-year old ch...     1     0   4296
# 35  b'i read the new yorker magazine and i enjoy s...     1     0   5932
# 36  b"'lake placid' is definately not your typical...     0     1   2275
# 37  b'for a movie about disco-era excess , " 54 " ...     0     1   5028
# 38  b' " a breed apart " casts rutger hauer as a c...     0     1   2314
# 39  b'it\'s probably inevitable that the popular v...     1     0   3765
# 40  b"carry on at your convenience is all about th...     1     0   3191
# 41  b' * * * the following review contains spoiler...     1     0  10998
# 42  b'the main problem with martin lawrence\'s pet...     1     0   3031
# 43  b"let me start off by saying that leading up t...     0     1   7775
# 44  b'miramax " disinvited " on-line media from pr...     1     0   5356

# %% [markdown]
# ## Listar "Peores" Errores
#
# Usemos las probabilidads para ver en qué se equivocó más fiero.

# %%
y_prob = pipeline.predict_proba(X_dev)

# %%
import pandas as pd
# pd.options.display.max_colwidth = 0

errors = []
for i, (x, y1, y2, y2p) in enumerate(zip(X_dev, y_dev, y_pred, y_prob)):
    if y1 != y2:
        diff = y2p[y1] - y2p[y2]
        errors.append({
            'index': i,
            'item': x,
            'true': y1,
            'pred': y2,
            'pneg': y2p[0],
            'ppos': y2p[1],
            'diff': diff})

errdf = pd.DataFrame(errors)
errdf.sort_values('diff', inplace=True)

# %%
errdf[:10]
# Out:
#         diff  index                                               item  \
# 44 -0.996120    294  b'miramax " disinvited " on-line media from pr...
# 40 -0.927204    268  b"carry on at your convenience is all about th...
# 14 -0.925333     96  b'plot : a little boy born in east germany ( n...
# 1  -0.829715      7  b' " the red violin " is a cold , sterile feat...
# 17 -0.820588    121  b'bob the happy bastard\'s quickie review : \n...
# 29 -0.817714    204  b'it was with great trepidation that i approac...
# 21 -0.797474    135  b'it might surprise some to know that joel and...
# 3  -0.719233     23  b'bob the happy bastard\'s quickie review : \n...
# 20 -0.711007    131  b"an indian runner was more than a courier . \...
# 32 -0.678771    237  b'what do you get when you combine clueless an...
#
#         pneg      ppos  pred  true
# 44  0.001940  0.998060     1     0
# 40  0.036398  0.963602     1     0
# 14  0.037334  0.962666     1     0
# 1   0.085142  0.914858     1     0
# 17  0.910294  0.089706     0     1
# 29  0.908857  0.091143     0     1
# 21  0.898737  0.101263     0     1
# 3   0.859616  0.140384     0     1
# 20  0.855503  0.144497     0     1
# 32  0.839385  0.160615     0     1

# %% [markdown]
# ## Inspeccionar un Error
#
# Agarremos un ejemplo y veamos qué sucede.

# %%
x = X_dev[294]
print(x.decode('utf-8'))
#[s for s in x.decode('utf-8').split('\n') if 'movie' in s]
# Out:
# miramax " disinvited " on-line media from press screenings of scream 3 .
# they ostensibly feared that folks like me would write spoiler-filled reviews and post them prior to the film's february 4th release date-unsound reasoning .
# you see , 'net critics established enough to be on any sort of vip list are professionals-miramax surely knows the difference between a member of the on-line film critics society ( ofcs ) and the type of fanboy who posts spy reports at ain't it cool news .
# no , the ? mini major' was afraid we'd let a bigger cat out of the bag than whodunit , that scream 3 is a dismal conclusion to the beloved ( by this writer , at least ) franchise .
# something smells rotten in the state of california right from the get-go : cotton weary ( liev schrieber ) , the former lover and would-be killer of maureen prescott , sidney's mother , is juggling phone calls in his luxury car .
#   - Las partes en las que se menciona la película (o 'movie').

# %%
vect = pipeline.named_steps['vect']
features = vect.get_feature_names()
neg_ws = 'dismal rotten clever disappointingly creaky silly laughless sanctimony woefully nightmare dissapoint'.split()
set(neg_ws) - set(features)
# Out:
# {'dissapoint', 'laughless', 'sanctimony'}

# %%
new_x = x.decode('utf-8').replace('dismal', 'bad')
pipeline.predict_proba([x, new_x])
# Out:
# array([[0.00193984, 0.99806016],
#        [0.00452386, 0.99547614]])

# %%
vect = pipeline.named_steps['vect']
clf = pipeline.named_steps['clf']
coef = clf.coef_
coef.shape
# Out:
# (1, 24642)

# %%
features = vect.get_feature_names()
x2 = vect.transform([x])
active = vect.inverse_transform(x2)[0]
active
# Out:
# array(['100', '13th', '4th', 'act', 'actress', 'acts', 'actually',
#        'advisor', 'afraid', 'ain', 'akin', 'alternative', 'american',
#        'american pop', 'american pop culture', 'appeal', 'arquette',
#        'articulate', 'aside', 'available', 'available video', 'bag',
#        'beings', 'beloved', 'bets', 'bigger', 'blatantly', 'bob',
#        'boyfriend', 'breaking', 'california', 'calls', 'cameo', 'camera',
#        'campbell', 'car', 'cat', 'character', 'chase', 'cheating',
#        'classmate', 'clever', 'climaxes', 'college', 'combination',
#        'come', 'comedy', 'coming', 'conclusion', 'considered', 'cool',
#        'costume', 'costumes', 'cotton', 'course', 'cox', 'craven',
#        'creaky', 'critics', 'crowd', 'cues', 'culture', 'danger', 'date',
#        'dated', 'death', 'denied', 'departure', 'detective', 'dewey',
#        'difference', 'direction', 'disappoint', 'disappointingly',
#        'dismal', 'distracting', 'door', 'draft', 'duo', 'effective',
#        'elaborate', 'electronic', 'established', 'estranged', 'exception',
#        'execution', 'existence', 'explain', 'far', 'feared', 'february',
#        'filled', 'film', 'film critics', 'finally', 'finishing', 'flicks',
#        'folks', 'follows', 'force', 'forced', 'franchise', 'friday',
#        'friday 13th', 'funny', 'gale', 'gale weathers', 'game', 'gates',
#        'gave', 'geek', 'generally', 'genre', 'gesture', 'gets',
#        'girlfriend', 'godfather', 'guessing', 'habit', 'halloween',
#        'heart', 'hide', 'horror', 'horror genre', 'hosts', 'human',
#        'human beings', 'identity', 'ignored', 'iii', 'imitation',
#        'immediately', 'incessantly', 'includes', 'incomprehensible',
#        'ingenue', 'instead', 'invented', 'ironic', 'jamie',
#        'jamie kennedy', 'jay', 'jay silent', 'jay silent bob', 'josh',
#        'juggling', 'kelly', 'kennedy', 'kevin', 'kevin smith',
#        'kevin williamson', 'killer', 'kind', 'knife', 'knows', 'kruger',
#        'lazy', 'let', 'liev', 'life', 'like', 'likely', 'line',
#        'line film', 'list', 'living', 'locks', 'look', 'lot', 'lover',
#        'luxury', 'major', 'master', 'maureen', 'media', 'member',
#        'memories', 'mickey', 'mind', 'mini', 'miramax', 'missing',
#        'moment', 'mother', 'motive', 'mouse', 'movie', 'movie gets',
#        'movie movie', 'movies', 'mulan', 'murder', 'music', 'mystery',
#        'mythology', 'needed', 'nerve', 'net', 'new', 'news', 'nightmare',
#        'nightmarish', 'notes', 'notion', 'novelty', 'occasional',
#        'ostensibly', 'outline', 'pains', 'pale', 'paranoid', 'parker',
#        'parker posey', 'parts', 'password', 'payoff', 'people',
#        'performances', 'perpetrator', 'personal', 'personality', 'peter',
#        'phone', 'place', 'plan', 'police', 'police detective', 'pop',
#        'pop culture', 'posey', 'possessed', 'post', 'potent', 'prescott',
#        'press', 'previous', 'prior', 'professionals', 'program',
#        'prologue', 'prospects', 'protected', 'radio', 'radio station',
#        'randy', 'readily', 'reasoning', 'reasons', 'recall', 'reference',
#        'reflection', 'regulars', 'release', 'release date', 'remaining',
#        'remains', 'reports', 'residence', 'respects', 'reviews', 'right',
#        'room', 'rotten', 'rule', 'rules', 'sadistic', 'save', 'saying',
#        'score', 'scream', 'scream scream', 'screams', 'screenings',
#        'screenplay', 'screenwriter', 'second', 'seeing', 'self', 'sequel',
#        'sequence', 'set', 'sheer', 'shelves', 'sidney', 'sidney prescott',
#        'significantly', 'silent', 'silent bob', 'silly', 'slacker',
#        'slasher', 'smells', 'smith', 'society', 'sort', 'spoiler',
#        'spring', 'spy', 'stab', 'stalking', 'stalks', 'stand', 'state',
#        'station', 'sting', 'store', 'superman', 'sure', 'surely',
#        'surviving', 'suspense', 'suspenseful', 'sweeping', 'talk',
#        'teacher', 'technical', 'tense', 'thrilling', 'tidy', 'tighter',
#        'time', 'timed', 'toned', 'trilogy', 'twice', 'type', 'unbearably',
#        'understand', 'unintentionally', 'universe', 'unspoken', 'video',
#        'video store', 'villainy', 'violence', 'visuals', 'waiting',
#        'wake', 'wardrobe', 'weary', 'weathers', 'wes', 'wes craven',
#        'whodunit', 'wielding', 'williamson', 'woefully', 'wonder',
#        'world', 'worn', 'write', 'writer'], dtype='<U43')

# %%
coef[x2.nonzero()]
# Out:
# array([ 7.46707137e-02, -6.07881591e-02,  3.24702186e-02, -3.20960576e-02,
#        -8.26177301e-02,  2.86623452e-02,  2.97099736e-02,  1.02419531e-01,
#        -5.34478850e-02,  2.24655147e-02,  2.12032040e-03,  3.48536312e-02,
#         3.97134842e-01,  2.81924462e-02,  2.81924462e-02, -1.03947843e-01,
#        -2.90210058e-02, -7.15029251e-03, -9.75696498e-03,  8.49456202e-02,
#         9.74311479e-03,  1.62097026e-02,  9.39678120e-02,  7.48764826e-02,
#        -4.43224084e-02, -6.41704409e-02, -5.96478271e-02,  1.11983883e-02,
#         4.59420816e-02, -2.44780940e-02,  5.06063880e-02, -5.20867085e-02,
#        -5.80600544e-02, -6.70297108e-03,  7.08489108e-02, -9.17564191e-02,
#        -8.50600287e-03,  7.34729176e-03,  8.65829381e-02, -2.63850536e-02,
#        -3.09672603e-02,  1.71081391e-01,  5.60834466e-02,  1.14672101e-01,
#         5.11535832e-02, -2.21458797e-01, -3.11064753e-01,  5.11307609e-02,
#         3.50202881e-02,  1.42962249e-02, -7.30518372e-02,  1.21660380e-02,
#        -1.06314899e-02,  1.37277279e-02,  1.72424618e-01, -2.96032725e-02,
#         4.68563694e-02, -1.19168893e-02,  9.65594129e-03,  3.85325830e-02,
#        -3.34793324e-03,  1.15857870e-01,  5.38327803e-02,  9.62085207e-02,
#         1.61528968e-02,  4.54993481e-03, -3.38736471e-02,  1.00436277e-01,
#         6.41186229e-03,  1.66766001e-02, -7.35483526e-02,  2.92225911e-01,
#         1.06899017e-01, -2.58370147e-02,  2.79142155e-02,  1.50862101e-01,
#         1.93432787e-02,  6.20486048e-03, -3.43679198e-02,  2.58689132e-01,
#         9.46946005e-03,  1.10251127e-02,  4.11096000e-02,  1.34480115e-01,
#         8.35030804e-02,  1.32445481e-02,  2.40783135e-02,  7.34481984e-03,
#        -1.41810775e-02, -2.25979737e-02,  1.74973005e-01,  9.86858769e-03,
#        -1.16758365e-01, -3.20730740e-02, -2.88191423e-02,  1.23577517e-01,
#         1.39437983e-01,  5.27114384e-02,  1.08910875e-01,  2.25738167e-03,
#         1.56391324e-01, -2.27408028e-02, -6.66335624e-02,  8.02882678e-03,
#         4.05435490e-02, -1.95268753e-02,  1.22988262e-02,  8.28551960e-02,
#         3.67654137e-01,  1.49511559e-01, -1.69768103e-02, -7.85091503e-02,
#         2.49773859e-02,  2.56637291e-02, -1.78714545e-01, -6.66374080e-02,
#         4.73669127e-02, -1.38290528e-01, -3.16796850e-03, -1.98750105e-02,
#        -3.04528716e-02, -2.48134166e-01, -1.54780888e-01, -5.15472596e-02,
#         1.05509818e-01,  1.56905102e-02, -6.58075779e-02,  9.59937292e-02,
#         1.32460519e-01,  2.40954732e-02,  2.38622567e-02,  4.37164356e-02,
#         1.10251127e-02,  1.72764343e-02, -9.24339326e-02,  5.15437178e-03,
#        -1.38453491e-01, -3.01088231e-03, -8.48387884e-03,  7.71136924e-03,
#         8.23989285e-02,  2.17737392e-01, -1.11929352e-01,  1.86817624e-02,
#         9.68492301e-02,  4.74682447e-02, -7.17771328e-03,  1.16344503e-02,
#        -5.45242629e-02,  7.90993471e-02,  9.77037443e-02,  1.23981773e-01,
#         6.70766980e-03,  6.50194852e-02, -1.96428686e-02,  1.21121138e-01,
#        -6.40803084e-03,  5.48870819e-02, -8.00620342e-02,  1.90567861e-01,
#         2.55097070e-03, -1.61804792e-02,  5.99455312e-02,  2.28029641e-02,
#         1.44285193e-01,  1.39037302e-01,  5.14443952e-02,  3.17129243e-02,
#        -7.02610726e-02, -2.04088485e-03, -7.92411629e-03,  7.11655968e-02,
#        -4.84996962e-02, -7.88407005e-02,  4.37559695e-03, -3.37195281e-02,
#         5.34948338e-03, -7.09502446e-04, -2.64715874e-03, -2.18374619e-01,
#         4.28180078e-02,  1.09919085e-02, -2.32491983e-02,  1.62826116e-02,
#        -9.93181243e-02, -4.84039783e-02, -3.53809906e-02,  4.20340339e-02,
#         1.16324894e-02, -3.81249972e-02,  4.68563694e-02,  3.02816133e-02,
#        -6.40784566e-02,  1.88164337e-02, -7.90633494e-04, -9.06495122e-02,
#         2.69273217e-01, -3.88315503e-02, -1.16822076e-01, -7.32787048e-02])

# %%
active_df = pd.DataFrame({'name': active, 'coef': coef[x2.nonzero()]})
active_df.sort_values('coef', inplace=True)
active_df[-20:]
# Out:
#              name      coef
# 54         course  0.172425
# 242         radio  0.174973
# 311   suspenseful  0.190568
# 189        movies  0.191495
# 293       society  0.217737
# 112         genre  0.224701
# 159          life  0.226431
# 172        master  0.228980
# 107          game  0.236412
# 213         parts  0.241621
# 183        mother  0.242069
# 99          force  0.254459
# 79      effective  0.258689
# 348         world  0.269273
# 71      direction  0.292226
# 98        follows  0.335835
# 216        people  0.362776
# 260         right  0.367654
# 12       american  0.397135
# 217  performances  0.452292

# %%
clf.decision_function(x2)
# clf.intercept_ + coef[x2.nonzero()].sum()
# Out:
# array([6.2432087])
